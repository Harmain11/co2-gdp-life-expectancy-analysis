# %% [markdown]
# # Importings Libraries

# %%
import os, sys, io, math, warnings
import numpy as np
import pandas as pd
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Loading and Standardize

# %%
URLS = {
    "co2": "https://ourworldindata.org/grapher/co-emissions-per-capita.csv",
    "gdp": "https://ourworldindata.org/grapher/gdp-per-capita-worldbank-constant-usd.csv",
    "life": "https://ourworldindata.org/grapher/life-expectancy.csv",
}

def load_csv(url):
    return pd.read_csv(url)

raw = {k: load_csv(u) for k, u in URLS.items()}

# %%
raw
